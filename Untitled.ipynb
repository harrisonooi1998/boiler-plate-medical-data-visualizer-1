# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('medical_examination.csv')

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.shape
# Out:
# (70000, 13)

# %%
df.tail
# Out:
# <bound method NDFrame.tail of           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
# ...

# %%
df.isna().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.head() #taking the head of the df
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df['height'] = df['height']/100 #converting to meters.

# %%
bmi = df['weight'] / (df['height']**2) #calculates BMI

# %%
df['BMI'] = bmi

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2    1.68    62.0    110     80            1     1
# 1          1  20228       1    1.56    85.0    140     90            3     1
# 2          2  18857       1    1.65    64.0    130     70            3     1
# 3          3  17623       2    1.69    82.0    150    100            1     1
# 4          4  17474       1    1.56    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2    1.68    76.0    120     80            1     1
# 69996  99995  22601       1    1.58   126.0    140     90            2     2
# 69997  99996  19066       2    1.83   105.0    180     90            3     1
# 69998  99998  22431       1    1.63    72.0    135     80            1     2
# 69999  99999  20540       1    1.70    72.0    120     80            2     1
#
# ...

# %%
df.loc[df['BMI'] >= 25, 'overweight'] = 0
df.loc[df['BMI'] < 25, 'not overweight'] = 1

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2    1.68    62.0    110     80            1     1      0
# 1   1  20228       1    1.56    85.0    140     90            3     1      0
# 2   2  18857       1    1.65    64.0    130     70            3     1      0
# 3   3  17623       2    1.69    82.0    150    100            1     1      0
# 4   4  17474       1    1.56    56.0    100     60            1     1      0
#
#    alco  active  cardio        BMI  overweight  not overweight
# 0     0       1       0  21.967120         NaN             1.0
# 1     0       1       1  34.927679         0.0             NaN
# 2     0       0       1  23.507805         NaN             1.0
# 3     0       1       1  28.710479         0.0             NaN
# 4     0       0       0  23.011177         NaN             1.0

# %% [markdown]
# ***Normalize the data by making 0 always good and 1 always bad. If the value of cholesterol or gluc is 1, make the value 0. If the value is more than 1, make the value 1***

# %%
df.loc[df['gluc'] == 1, 'gluc'] = 0 
df.loc[df['gluc'] > 1, 'gluc'] = 1 

df.loc[df['cholesterol'] == 1, 'cholesterol'] = 0 
df.loc[df['cholesterol'] > 1, 'cholesterol'] = 1

# %%
df['cholesterol'].unique() #finding the cholesterol
# Out:
# array([0, 1], dtype=int64)

# %%
df['gluc'].unique() #finding the cholesterol
# Out:
# array([0, 1], dtype=int64)

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2    1.68    62.0    110     80            0     0
# 1          1  20228       1    1.56    85.0    140     90            1     0
# 2          2  18857       1    1.65    64.0    130     70            1     0
# 3          3  17623       2    1.69    82.0    150    100            0     0
# 4          4  17474       1    1.56    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2    1.68    76.0    120     80            0     0
# 69996  99995  22601       1    1.58   126.0    140     90            1     1
# 69997  99996  19066       2    1.83   105.0    180     90            1     0
# 69998  99998  22431       1    1.63    72.0    135     80            0     1
# 69999  99999  20540       1    1.70    72.0    120     80            1     0
#
# ...

# %% [markdown]
# <h1>
# Convert the data into long format and create a chart that shows the value counts of the categorical features using seaborn's catplot(). The dataset should be split by 'Cardio' so there is one chart for each cardio value. The chart should look like examples/Figure_1.png. <h1>

# %%
df.head() #quick glance at the data.
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2    1.68    62.0    110     80            0     0      0
# 1   1  20228       1    1.56    85.0    140     90            1     0      0
# 2   2  18857       1    1.65    64.0    130     70            1     0      0
# 3   3  17623       2    1.69    82.0    150    100            0     0      0
# 4   4  17474       1    1.56    56.0    100     60            0     0      0
#
#    alco  active  cardio        BMI  overweight  not overweight
# 0     0       1       0  21.967120         NaN             1.0
# 1     0       1       1  34.927679         0.0             NaN
# 2     0       0       1  23.507805         NaN             1.0
# 3     0       1       1  28.710479         0.0             NaN
# 4     0       0       0  23.011177         NaN             1.0

# %%
df_cat = df.melt(id_vars = 'cardio', value_vars = ['active','alco','cholesterol','gluc','overweight','smoke'])
df_cat
# Out:
#         cardio variable  value
# 0            0   active    1.0
# 1            1   active    1.0
# 2            1   active    0.0
# 3            1   active    1.0
# 4            0   active    0.0
# ...        ...      ...    ...
# 419995       0    smoke    1.0
# 419996       1    smoke    0.0
# 419997       1    smoke    0.0
# 419998       1    smoke    0.0
# 419999       0    smoke    0.0
#
# [420000 rows x 3 columns]

# %%
# Draw Categorical Plot
def draw_cat_plot():
    df_cat = pd.melt(df, id_vars = 'cardio', value_vars = ['cholesterol', 'gluc', 'smoke', 
                                    'alco', 'active', 'overweight'])
    fig = sns.catplot(data=df_cat, kind='count', x='variable', hue='value', col='cardio')
    fig

# %% [markdown]
# <h1> Clean the data. Filter out the following patient segments that represent incorrect data:
# diastolic pressure is higher than systolic (Keep the correct data with (df['ap_lo'] <= df['ap_hi']))
# height is less than the 2.5th percentile (Keep the correct data with (df['height'] >= df['height'].quantile(0.025)))
# height is more than the 97.5th percentile
# weight is less than the 2.5th percentile
# weight is more than the 97.5th percentile <h1>

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2    1.68    62.0    110     80            0     0      0
# 1   1  20228       1    1.56    85.0    140     90            1     0      0
# 2   2  18857       1    1.65    64.0    130     70            1     0      0
# 3   3  17623       2    1.69    82.0    150    100            0     0      0
# 4   4  17474       1    1.56    56.0    100     60            0     0      0
#
#    alco  active  cardio        BMI  overweight  not overweight
# 0     0       1       0  21.967120         NaN             1.0
# 1     0       1       1  34.927679         0.0             NaN
# 2     0       0       1  23.507805         NaN             1.0
# 3     0       1       1  28.710479         0.0             NaN
# 4     0       0       0  23.011177         NaN             1.0

# %%
#this is the cleaned data. 
filtered_patients = df[(df['ap_lo'] <= df['ap_hi']) & 
(df['height'] >= df['height'].quantile(0.025)) &
(df['height'] <= df['height'].quantile(0.975)) &
(df['weight'] >= df['weight'].quantile(0.025)) & 
(df['weight'] <= df['weight'].quantile(0.975)) ]

# %%
filtered_patients.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2    1.68    62.0    110     80            0     0      0
# 1   1  20228       1    1.56    85.0    140     90            1     0      0
# 2   2  18857       1    1.65    64.0    130     70            1     0      0
# 3   3  17623       2    1.69    82.0    150    100            0     0      0
# 4   4  17474       1    1.56    56.0    100     60            0     0      0
#
#    alco  active  cardio        BMI  overweight  not overweight
# 0     0       1       0  21.967120         NaN             1.0
# 1     0       1       1  34.927679         0.0             NaN
# 2     0       0       1  23.507805         NaN             1.0
# 3     0       1       1  28.710479         0.0             NaN
# 4     0       0       0  23.011177         NaN             1.0

# %%
filtered_patients.corr()
# Out:
#                       id       age    gender    height    weight     ap_hi  \
# id              1.000000  0.002507  0.003426  0.000326  0.000149  0.003492
# age             0.002507  1.000000 -0.018132 -0.076932  0.070168  0.018689
# gender          0.003426 -0.018132  1.000000  0.505785  0.129979  0.005063
# height          0.000326 -0.076932  0.505785  1.000000  0.251503  0.004586
# weight          0.000149  0.070168  0.129979  0.251503  1.000000  0.027030
# ap_hi           0.003492  0.018689  0.005063  0.004586  0.027030  1.000000
# ap_lo           0.000484  0.153508  0.059947  0.017922  0.227922  0.072803
# cholesterol     0.003719  0.129996 -0.037605 -0.063522  0.135981  0.022807
# gluc            0.002289  0.086990 -0.021357 -0.030469  0.107072  0.011111
# smoke          -0.002732 -0.044371  0.337436  0.187830  0.056533 -0.001928
# alco           -0.000708 -0.026970  0.168637  0.089785  0.059917  0.000769
# ...

# %%
sns.heatmap(filtered_patients.corr())

# %%
plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True
mask = np.triu(np.ones_like(filtered_patients.corr(), dtype=np.bool))
heatmap = sns.heatmap(filtered_patients.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18}, pad=16);
